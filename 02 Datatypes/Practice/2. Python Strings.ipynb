# %% [markdown]
# # Practice — Strings
#
# **This is scratch space, not teaching material.** It holds working notes against the
# string assignment in `2. String Assignment.docx` in this folder.
#
# The taught content lives in **[2.1 Python Strings Datatype](../2.1%20Python%20Strings%20Datatype.ipynb)**;
# its exercises are in the *Practice Exercises* cell at the end of that notebook.
#
# Left deliberately unpolished — solve the problems here, break things, and don't worry
# about tidiness.
#
# ---

# %% [markdown]
# ### 4.

# %%
st1,st2='abc','xyz'
concat= st1.replace(st1[:2],st2[:2])+' '+st2.replace(st2[:2],st1[:2])
print(concat)
